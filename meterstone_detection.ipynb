# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wbuGG7jWtGcAgBFVTtql")
project = rf.workspace("shashidhar-kalapatapu").project("meterstone-sample-1")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 828.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics
# !cd ultralytics
# !pip install -e ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 20927, done.
# remote: Counting objects: 100% (1368/1368), done.
# remote: Compressing objects: 100% (836/836), done.
# remote: Total 20927 (delta 823), reused 832 (delta 515), pack-reused 19559
# Receiving objects: 100% (20927/20927), 12.39 MiB | 20.01 MiB/s, done.
# Resolving deltas: 100% (14500/14500), done.
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.5-0.editable-py3-none-any.whl size=22614 sha256=3346005fee67baac8f94e02e44747f7d3faaeefba36976aefff6626a232a3ea4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b7hwvym3/wheels/9a/cd/d5/95912172899f8ec640166ff6eef49156b1b00d6b2ade4a3cb1
# ...

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=/content/meterstone-sample-1-2/data.yaml \
epochs=100 \
imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 149MB/s]
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/ultralytics/runs/detect/train/weights/best.pt \
conf=0.25 \
source=/content/meterstone-sample-1-2/valid/images
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/205 /content/meterstone-sample-1-2/valid/images/db_kmstone_final_work_100_jpg.rf.3e2eca55643dec342417a0acf8e6464a.jpg: 640x480 2 meterstones, 97.2ms
# image 2/205 /content/meterstone-sample-1-2/valid/images/db_kmstone_final_work_101_jpg.rf.28068a46c28843b6d92859fc1ac9538d.jpg: 640x480 1 meterstone, 12.1ms
# image 3/205 /content/meterstone-sample-1-2/valid/images/db_kmstone_final_work_103_jpg.rf.9ca00ca45486f7bc8c165865d0056781.jpg: 640x384 1 meterstone, 69.5ms
# image 4/205 /content/meterstone-sample-1-2/valid/images/db_kmstone_final_work_104_jpg.rf.fb158b9643bd1577fc3bf448bed12d0a.jpg: 640x384 1 meterstone, 10.7ms
# image 5/205 /content/meterstone-sample-1-2/valid/images/db_kmstone_final_work_110_jpg.rf.edc78bf88dd1f7b747231d713aaa0283.jpg: 640x480 1 meterstone, 13.2ms
# ...

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')

# Define the source folder path in Colab
source_folder = '/content/ultralytics/runs/detect/train'

# Define the destination folder path in Google Drive
destination_folder = '/content/drive/My Drive/Your_Destination_Folder'

# Copy the entire folder to Google Drive
shutil.copytree(source_folder, destination_folder)

# Unmount Google Drive (optional)
drive.flush_and_unmount()

print(f"Folder '{source_folder}' has been copied to '{destination_folder}' in your Google Drive.")
# Out:
# Mounted at /content/drive
# Folder '/content/ultralytics/runs/detect/train' has been copied to '/content/drive/My Drive/Your_Destination_Folder' in your Google Drive.
